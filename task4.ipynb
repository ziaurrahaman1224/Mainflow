# %%
from tkinter import *
from PIL import ImageTk, Image

# function to initialize the calculator
def init_calc():
    rz = Tk()
    rz.title("𝗖𝗮𝗹𝗰𝘂𝗹𝗮𝘁𝗼𝗿")
   
    # change the path of ico file name
    rz.iconbitmap('C:\\Users\\ziaur\\Downloads\\t4\\iconcalc.ico')
    rz.geometry("370x380")
   
    # change the path of background file name
    bg = ImageTk.PhotoImage(file="C:\\Users\\ziaur\\Downloads\\iconbgc.png")
    bg_lbl = Label(rz, image=bg)
    bg_lbl.place(x=0, y=0)
   
    # Entry Widget
    e = Entry(rz, width=35, borderwidth=13, font=("Times", 10))
    e.grid(row=0, column=0, pady=20, padx=30, columnspan=3)
   
    # Load images
    images = {
        "0": ImageTk.PhotoImage(file="C:\\Users\\ziaur\\Downloads\\t4\\icon0.png"),
        "1": ImageTk.PhotoImage(file="C:\\Users\\ziaur\\Downloads\\t4\\icon1.png"),
        "2": ImageTk.PhotoImage(file="C:\\Users\\ziaur\\Downloads\\t4\\icon2.png"),
        "3": ImageTk.PhotoImage(file="C:\\Users\\ziaur\\Downloads\\t4\\icon3.png"),
        "4": ImageTk.PhotoImage(file="C:\\Users\\ziaur\\Downloads\\t4\\icon4.png"),
        "5": ImageTk.PhotoImage(file="C:\\Users\\ziaur\\Downloads\\t4\\icon5.png"),
        "6": ImageTk.PhotoImage(file="C:\\Users\\ziaur\\Downloads\\t4\\icon6.png"),
        "7": ImageTk.PhotoImage(file="C:\\Users\\ziaur\\Downloads\\t4\\icon7.png"),
        "8": ImageTk.PhotoImage(file="C:\\Users\\ziaur\\Downloads\\t4\\icon8.png"),
        "9": ImageTk.PhotoImage(file="C:\\Users\\ziaur\\Downloads\\t4\\icon9.png"),
        "+": ImageTk.PhotoImage(file="C:\\Users\\ziaur\\Downloads\\t4\\iconplus.png"),
        "-": ImageTk.PhotoImage(file="C:\\Users\\ziaur\\Downloads\\t4\\iconminus.png"),
        "*": ImageTk.PhotoImage(file="C:\\Users\\ziaur\\Downloads\\t4\\iconmultiply.png"),
        "/": ImageTk.PhotoImage(file="C:\\Users\\ziaur\\Downloads\\t4\\icondivide.png"),
        "=": ImageTk.PhotoImage(file="C:\\Users\\ziaur\\Downloads\\t4\\iconequal.png"),
        "C": ImageTk.PhotoImage(file="C:\\Users\\ziaur\\Downloads\\t4\\iconC.png"),
    }
   
    def butt_click(num):
        curr = e.get()
        e.delete(0, END)
        e.insert(0, str(curr) + str(num))
       
    def butt_add():
        fnum = e.get()
        global f_num
        global maths
        maths = "addition"
        f_num = int(fnum)
        e.delete(0, END)
       
    def butt_sub():
        fnum = e.get()
        global f_num
        global msths
        maths = "subtraction"
        f_num = int(fnum)
        e.delete(0, END)
       
    def butt_div():
        fnum = e.get()
        global f_num
        global maths
        maths = "division"
        f_num = int(fnum)
        e.delete(0, END)
       
    def butt_mul():
        fnum = e.get()
        global f_num
        global maths
        maths = "multiplication"
        f_num = int(fnum)
        e.delete(0, END)
       
    def butt_equal():
        snum = e.get()
        e.delete(0, END)
        if maths == "addition":
            e.insert(0, f_num + int(snum))
        if maths == "subtraction":
            e.insert(0, f_num - int(snum))
        if maths == "multiplication":
            e.insert(0, f_num * int(snum))
        if maths == "division":
            e.insert(0, f_num / int(snum))
           
    def butt_clear():
        e.delete(0, END)
       
    # defining buttons
    buttons = {
        "1": (3, 0, lambda: butt_click(1)),
        "2": (3, 1, lambda: butt_click(2)),
        "3": (3, 2, lambda: butt_click(3)),
        "4": (2, 0, lambda: butt_click(4)),
        "5": (2, 1, lambda: butt_click(5)),
        "6": (2, 2, lambda: butt_click(6)),
        "7": (1, 0, lambda: butt_click(7)),
        "8": (1, 1, lambda: butt_click(8)),
        "9": (1, 2, lambda: butt_click(9)),
        "0": (4, 1, lambda: butt_click(0)),
        "+": (1, 3, butt_add),
        "-": (2, 3, butt_sub),
        "*": (3, 3, butt_mul),
        "/": (4, 3, butt_div),
        "=": (4, 2, butt_equal),
        "C": (4, 0, butt_clear),
    }
   
    for btn, (row, col, cmd) in buttons.items():
        Button(rz, border="3", image=images[btn], command=cmd).grid(row=row, column=col)
   
    # keep references to images
    rz.images = images
   
    rz.mainloop()
# Initialize the calculator
init_calc()
